# %% [markdown]
# <a href="https://colab.research.google.com/github/kael89-99/function-from-zero/blob/main/statements_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Learning Statements

# %%
print('test1')
# Out:
# test1

# %% [markdown]
# ###variables

# %%
variabl = 7

# %% [markdown]
# ### Data Structures

# %% [markdown]
# ####List

# %%
my_list = [1,3,7,9]

# %%
my_list[2]
# Out:
# 7

# %% [markdown]
# #### Dictionary

# %%
my_dict = {1:'one', 3:'three'}

# %%
type(my_dict)
# Out:
# dict

# %%
my_dict.values()
# Out:
# dict_values(['one', 'three'])

# %% [markdown]
# #### Loops

# %%
for key,value in my_dict.items():
  print(f'this is my key: {key}')
  print(f'this is my value: {value}')
# Out:
# this is my key: 1
# this is my value: one
# this is my key: 3
# this is my value: three

# %%
for items in my_list:
  print(f'this is the value in the list: {items}')
# Out:
# this is the value in the list: 1
# this is the value in the list: 3
# this is the value in the list: 7
# this is the value in the list: 9
